# %%
# %run ../IDS_smooth_local.py
# %run ../rule_miner.py 
# %run ../rules.py

# %run C:/code/python/CBA/main.py

# %%
import pyarc
from pyarc.data_structures import TransactionDB
import matplotlib.pyplot as plt
import matplotlib.patches as patches

plt.style.use("ggplot")

import pandas as pd
import numpy
import re

import copy
import random

movies = pd.read_csv("../data/movies.csv", sep=";")
movies_discr = movies.copy(True)

budget_bins = range(0, 350, 50)
budget_bins_names = [ "<{0};{1})".format(i, i + 50) for i in budget_bins[:-1] ]

celebrities_bins = range(0, 10, 2)
celebrities_bins_names = [ "<{0};{1})".format(i, i + 2) for i in celebrities_bins[:-1] ]


transactionDB = TransactionDB.from_DataFrame(movies_discr, unique_transactions=True)

movies_vals = movies.get_values()

x = range(0, 350, 50)
y = range(1, 9)


x_points = list(map(lambda n: n[0], movies_vals))
y_points = list(map(lambda n: n[1], movies_vals))
data_class = list(movies['class'])
appearance = {
    'box-office-bomb': ('brown', "o"),
    'main-stream-hit': ('blue', "o"),
    'critical-success': ('green', "o")
}
rule_appearance = {
    'box-office-bomb': 'tan',
    'main-stream-hit': 'aqua',
    'critical-success': 'lightgreen'
}

plt.style.use('seaborn-white')


def plot_qrule(qrule, plt):
    interval_regex = "(?:<|\()(\d+(?:\.(?:\d)+)?);(\d+(?:\.(?:\d)+)?)(?:\)|>)"
    
    lower_y = 0
    area_y = celebrities_bins[-1]
    
    lower_x = 0
    area_x = budget_bins[-1]
    
    antecedent = qrule.antecedent
    
    
    if len(antecedent) != 0:
        if antecedent[0][0] == "a-list-celebrities":
            y = antecedent[0]
            y_boundaries = re.search(interval_regex, repr(y[1]))
            lower_y = float(y_boundaries.group(1))
            upper_y = float(y_boundaries.group(2))
            area_y = upper_y - lower_y

            axis = plt.gca()
        else:
            x = antecedent[0]
            x_boundaries = re.search(interval_regex, repr(x[1]))
            lower_x = float(x_boundaries.group(1))
            upper_x = float(x_boundaries.group(2))
            area_x = upper_x - lower_x
        
    if len(antecedent) > 1:
        if antecedent[1][0] == "a-list-celebrities":
            y = antecedent[0]
            y_boundaries = re.search(interval_regex, repr(y[1]))
            lower_y = float(y_boundaries.group(1))
            upper_y = float(y_boundaries.group(2))
            area_y = upper_y - lower_y

            axis = plt.gca()
        else:
            x = antecedent[1]
            x_boundaries = re.search(interval_regex, repr(x[1]))
            lower_x = float(x_boundaries.group(1))
            upper_x = float(x_boundaries.group(2))
            area_x = upper_x - lower_x
            
    
    axis = plt.gca()

    class_name = qrule.consequent[1]
    
    axis.add_patch(
       patches.Rectangle((lower_x, lower_y), area_x, area_y, zorder=-2, facecolor=rule_appearance[class_name], alpha=qrule.confidence)
    )




def plot_IDS_rule(rule, plt):
    interval_regex = "<(\d+);(\d+)\)"
    
    lower_y = 0
    area_y = celebrities_bins[-1]
    
    lower_x = 0
    area_x = budget_bins[-1]
    
    
    itemset = list(rule.itemset)
    
    
    if len(itemset) != 0:
        if itemset[0][0] == "a-list-celebrities":
            y = itemset[0]
            y_boundaries = re.search(interval_regex, y[1])
            lower_y = float(y_boundaries.group(1))
            upper_y = float(y_boundaries.group(2))
            area_y = upper_y - lower_y

            axis = plt.gca()
        else:
            x = itemset[0]
            x_boundaries = re.search(interval_regex, x[1])
            lower_x = float(x_boundaries.group(1))
            upper_x = float(x_boundaries.group(2))
            area_x = upper_x - lower_x
        
    if len(itemset) > 1:
        if itemset[1][0] == "a-list-celebrities":
            y = itemset[1]
            y_boundaries = re.search(interval_regex, y[1])
            lower_y = float(y_boundaries.group(1))
            upper_y = float(y_boundaries.group(2))
            area_y = upper_y - lower_y

            axis = plt.gca()
        else:
            x = itemset[1]
            x_boundaries = re.search(interval_regex, x[1])
            lower_x = float(x_boundaries.group(1))
            upper_x = float(x_boundaries.group(2))
            area_x = upper_x - lower_x
            
    
    axis = plt.gca()

    class_name = rule.class_label
    
    axis.add_patch(
       patches.Rectangle((lower_x, lower_y), area_x, area_y, zorder=-2, facecolor=rule_appearance[class_name], alpha=0.8)
    )


def plot_rule(rule, plt):
    interval_regex = "<(\d+);(\d+)\)"
    
    lower_y = 0
    area_y = celebrities_bins[-1]
    
    lower_x = 0
    area_x = budget_bins[-1]
    
    
    
    
    if len(rule.antecedent) != 0:
        if rule.antecedent[0][0] == "a-list-celebrities":
            y = rule.antecedent[0]
            y_boundaries = re.search(interval_regex, y[1])
            lower_y = float(y_boundaries.group(1))
            upper_y = float(y_boundaries.group(2))
            area_y = upper_y - lower_y

            axis = plt.gca()
        else:
            x = rule.antecedent[0]
            x_boundaries = re.search(interval_regex, x[1])
            lower_x = float(x_boundaries.group(1))
            upper_x = float(x_boundaries.group(2))
            area_x = upper_x - lower_x
        
    if len(rule.antecedent) > 1:
        if rule.antecedent[1][0] == "a-list-celebrities":
            y = rule.antecedent[1]
            y_boundaries = re.search(interval_regex, y[1])
            lower_y = float(y_boundaries.group(1))
            upper_y = float(y_boundaries.group(2))
            area_y = upper_y - lower_y

            axis = plt.gca()
        else:
            x = rule.antecedent[1]
            x_boundaries = re.search(interval_regex, x[1])
            lower_x = float(x_boundaries.group(1))
            upper_x = float(x_boundaries.group(2))
            area_x = upper_x - lower_x
            
    
    axis = plt.gca()

    class_name = rule.consequent[1]
    
    axis.add_patch(
       patches.Rectangle((lower_x, lower_y), area_x, area_y, zorder=-2, facecolor=rule_appearance[class_name], alpha=rule.confidence)
    )



def plot_quant_rules(qrules):
    for r in qrules:
        plot_qrule(r, plt)

    # data cases
    for i in range(len(x_points)):
        plt.scatter(x_points[i], y_points[i], marker=appearance[data_class[i]][1], color=appearance[data_class[i]][0], s=60)


    # rule boundary lines
    for i, n in enumerate(x):
        plt.axhline(y=y[i], color = "grey", linestyle="dashed")
        plt.axvline(x=x[i], color = "grey", linestyle="dashed")

        
        
    plt.xlabel('Estimated Budget (1000$)')
    plt.ylabel('A-List Celebrities')

    
def plot_IDS_rules(rules):
    for r in rules:
        plot_IDS_rule(r, plt)

    # data cases
    for i in range(len(x_points)):
        plt.scatter(x_points[i], y_points[i], marker=appearance[data_class[i]][1], color=appearance[data_class[i]][0], s=60)


    # rule boundary lines
    for i, n in enumerate(x):
        plt.axhline(y=y[i], color = "grey", linestyle="dashed")
        plt.axvline(x=x[i], color = "grey", linestyle="dashed")

        
        
    plt.xlabel('Estimated Budget (1000$)')
    plt.ylabel('A-List Celebrities')


def plot_rules(rules):
    for r in rules:
        plot_rule(r, plt)

    # data cases
    for i in range(len(x_points)):
        plt.scatter(x_points[i], y_points[i], marker=appearance[data_class[i]][1], color=appearance[data_class[i]][0], s=60)


    # rule boundary lines
    for i, n in enumerate(x):
        plt.axhline(y=y[i], color = "grey", linestyle="dashed")
        plt.axvline(x=x[i], color = "grey", linestyle="dashed")

        
        
    plt.xlabel('Estimated Budget (1000$)')
    plt.ylabel('A-List Celebrities')

# %%
import pandas as pd
import numpy as np


from multiprocessing import Pool


from sklearn.metrics import accuracy_score

from pyarc import TransactionDB
from pyarc.algorithms import (
    top_rules,
    createCARs,
    M1Algorithm
)
from pyarc import CBA, TransactionDB
        


"""
lambda_array = [1.0]*7     # use separate hyperparamter search routine
s1 = smooth_local_search(list_of_rules, df, Y, lambda_array, 0.33, 0.33)
s2 = smooth_local_search(list_of_rules, df, Y, lambda_array, 0.33, -1.0)
f1 = func_evaluation(s1, list_of_rules, df, Y, lambda_array)
f2 = func_evaluation(s2, list_of_rules, df, Y, lambda_array)

result_set = {}
if f1 > f2:
    print("The Solution Set is: "+str(s1))
    result_set = list(s1)
else:
    print("The Solution Set is: "+str(s2))
    result_set = list(s2)
"""

df = pd.read_csv('../data/movies_discr.csv', ';')
df = df.iloc[:,1:]
df_raw = df.iloc[:, :-1]
Y = df.iloc[:, -1]

txns_train = TransactionDB.from_DataFrame(df)

rules = run_fim_apriori(df_raw, 0.1)
list_of_rules = createrules(rules, list(set(Y)))

prepare_caches(list_of_rules, df, Y)
prepare_overlap(list_of_rules, df)

def optimize(param):
    #lambda_array = [1.0]*7     # use separate hyperparamter search routine
    lambda_array = [1, 0, 0, 1, 0, 0, 0]
    
    s1 = smooth_local_search(list_of_rules, df, Y, lambda_array, 0.33, param)
    f1 = func_evaluation(s1, list_of_rules, df, Y, lambda_array, len(list_of_rules))

    return f1, s1

def f(x):
    return x * x

if __name__ == "__main__":
   

    print("---------------------")
    print("Training CBA model")
    print("---------------------")

    cba = CBA(support=0.01, confidence=0, algorithm="m1")
    cba.fit(txns_train)

    cba_accuracy = cba.rule_model_accuracy(txns_train)

    # precompute values for cover and correct cover
    

    print("---------------------")
    print("All mined rules for IDS")
    print("---------------------")
    for r in list_of_rules:
        r.print_rule()

    print("---------------------")
    print("Starting SLS")
    print("---------------------")
    

    

    
    results = list(map(optimize, [0.33, -1.0]))

    #results = process_pool.map(f, [2, 3])

    (f1, s1), (f2, s2) = results 

    result_set = {}
    if f1 > f2:
        print("The Solution Set is: "+str(s1))
        result_set = list(s1)
    else:
        print("The Solution Set is: "+str(s2))
        result_set = list(s2)




    np_rules = np.array(list_of_rules)
    solution_rules = np_rules[result_set]

    print("---------------------")
    print("IDS rules")
    print("---------------------")
    for r in solution_rules:
        r.print_rule()
    
    print("---------------------")
    print("CBA rules")
    print("---------------------")
    for r in cba.clf.rules:
        print(r)

    print("----------------------")

    pred = predict(result_set, list_of_rules, df, Y)
    print("IDS accuracy", accuracy_score(pred, Y))
    print("CBA accuracy", cba_accuracy)
# Out:
# running fim apriori function
# dataset processed
# apriori runned
# apriori results processed
# ---------------------
# Training CBA model
# ---------------------
# ---------------------
# All mined rules for IDS
# ---------------------
# If estimated-budget == <100;150), then box-office-bomb
# If estimated-budget == <100;150), then critical-success
# If estimated-budget == <100;150), then main-stream-hit
# If estimated-budget == <150;200), then box-office-bomb
# If estimated-budget == <150;200), then critical-success
# If estimated-budget == <150;200), then main-stream-hit
# If a-list-celebrities == <2;4) and estimated-budget == <150;200), then box-office-bomb
# If a-list-celebrities == <2;4) and estimated-budget == <150;200), then critical-success
# If a-list-celebrities == <2;4) and estimated-budget == <150;200), then main-stream-hit
# If estimated-budget == <0;50), then box-office-bomb
# If estimated-budget == <0;50), then critical-success
# If estimated-budget == <0;50), then main-stream-hit
# If estimated-budget == <0;50) and a-list-celebrities == <0;2), then box-office-bomb
# If estimated-budget == <0;50) and a-list-celebrities == <0;2), then critical-success
# If estimated-budget == <0;50) and a-list-celebrities == <0;2), then main-stream-hit
# If a-list-celebrities == <4;6), then box-office-bomb
# If a-list-celebrities == <4;6), then critical-success
# If a-list-celebrities == <4;6), then main-stream-hit
# If a-list-celebrities == <0;2), then box-office-bomb
# If a-list-celebrities == <0;2), then critical-success
# If a-list-celebrities == <0;2), then main-stream-hit
# If estimated-budget == <50;100), then box-office-bomb
# If estimated-budget == <50;100), then critical-success
# If estimated-budget == <50;100), then main-stream-hit
# If a-list-celebrities == <2;4) and estimated-budget == <50;100), then box-office-bomb
# If a-list-celebrities == <2;4) and estimated-budget == <50;100), then critical-success
# If a-list-celebrities == <2;4) and estimated-budget == <50;100), then main-stream-hit
# If a-list-celebrities == <2;4), then box-office-bomb
# If a-list-celebrities == <2;4), then critical-success
# If a-list-celebrities == <2;4), then main-stream-hit
# ---------------------
# Starting SLS
# ---------------------
# 2/n*n OPT value is 69.85333333333334
# Estimating omega for rule 0
# Standard Error 11.485338479992656
# Estimating omega for rule 1
# Standard Error 15.593075386209097
# Estimating omega for rule 2
# Standard Error 13.96527837173323
# Estimating omega for rule 3
# Standard Error 17.060275496017056
# Estimating omega for rule 4
# Standard Error 16.449741639308503
# Estimating omega for rule 5
# Standard Error 13.906868806456757
# Estimating omega for rule 6
# Standard Error 14.96061496062244
# Estimating omega for rule 7
# Standard Error 15.979392979709836
# Estimating omega for rule 8
# Standard Error 16.24493767301063
# Estimating omega for rule 9
# Standard Error 20.03169987794346
# Estimating omega for rule 10
# Standard Error 17.150189503326196
# Estimating omega for rule 11
# Standard Error 23.843930045191797
# Estimating omega for rule 12
# Standard Error 12.073152032505844
# Estimating omega for rule 13
# Standard Error 30.213242129900593
# Estimating omega for rule 14
# Standard Error 20.10276100439937
# Estimating omega for rule 15
# Standard Error 15.910373974234545
# Estimating omega for rule 16
# Standard Error 15.859161390187062
# Estimating omega for rule 17
# Standard Error 19.939633898344272
# Estimating omega for rule 18
# Standard Error 18.621412406152224
# Estimating omega for rule 19
# Standard Error 11.936247316472627
# Estimating omega for rule 20
# Standard Error 17.35857136978732
# Estimating omega for rule 21
# Standard Error 21.99904543383644
# Estimating omega for rule 22
# Standard Error 17.542320257024155
# Estimating omega for rule 23
# Standard Error 15.903018581388881
# Estimating omega for rule 24
# Standard Error 17.113152836341992
# Estimating omega for rule 25
# Standard Error 20.856797453108662
# Estimating omega for rule 26
# Standard Error 18.369784974245068
# Estimating omega for rule 27
# Standard Error 18.271863615953354
# Estimating omega for rule 28
# Standard Error 13.852292229086132
# Estimating omega for rule 29
# Standard Error 13.02006144378743
# 2/n*n OPT value is 69.78888888888889
# Estimating omega for rule 0
# Standard Error 13.709704592003432
# Estimating omega for rule 1
# Standard Error 16.89112192839777
# Estimating omega for rule 2
# Standard Error 14.461258589763204
# Estimating omega for rule 3
# Standard Error 21.882070285967004
# Estimating omega for rule 4
# Standard Error 15.45451390371111
# Estimating omega for rule 5
# Standard Error 15.428707009986288
# Estimating omega for rule 6
# Standard Error 14.96943552709988
# Estimating omega for rule 7
# Standard Error 15.116117226325018
# Estimating omega for rule 8
# Standard Error 14.908957039310295
# Estimating omega for rule 9
# Standard Error 13.516101508941105
# Estimating omega for rule 10
# Standard Error 12.536666223522106
# Estimating omega for rule 11
# Standard Error 25.153786991226593
# Estimating omega for rule 12
# Standard Error 15.323348198092999
# Estimating omega for rule 13
# Standard Error 17.5781967220759
# Estimating omega for rule 14
# Standard Error 13.162978386368337
# Estimating omega for rule 15
# Standard Error 19.03969537571439
# Estimating omega for rule 16
# Standard Error 13.484250071843077
# Estimating omega for rule 17
# Standard Error 19.217179813906096
# Estimating omega for rule 18
# Standard Error 19.486328540800084
# Estimating omega for rule 19
# Standard Error 18.64127141586646
# Estimating omega for rule 20
# Standard Error 18.66890462774932
# Estimating omega for rule 21
# Standard Error 15.945689072598903
# Estimating omega for rule 22
# Standard Error 17.57464082136531
# Estimating omega for rule 23
# Standard Error 15.815467112924614
# Estimating omega for rule 24
# Standard Error 16.5752224721118
# Estimating omega for rule 25
# Standard Error 23.245838337216405
# Estimating omega for rule 26
# Standard Error 13.850054151518687
# Estimating omega for rule 27
# Standard Error 16.853545621025862
# Estimating omega for rule 28
# Standard Error 17.476555724741647
# Estimating omega for rule 29
# Standard Error 16.127771079724564
# The Solution Set is: {1, 3, 14, 15, 21, 23, 24}
# ---------------------
# IDS rules
# ---------------------
# If estimated-budget == <100;150), then critical-success
# If estimated-budget == <150;200), then box-office-bomb
# If estimated-budget == <0;50) and a-list-celebrities == <0;2), then main-stream-hit
# If a-list-celebrities == <4;6), then box-office-bomb
# If estimated-budget == <50;100), then box-office-bomb
# If estimated-budget == <50;100), then main-stream-hit
# If a-list-celebrities == <2;4) and estimated-budget == <50;100), then box-office-bomb
# ---------------------
# CBA rules
# ---------------------
# CAR {a-list-celebrities=<0;2)} => {class=box-office-bomb} sup: 0.31 conf: 1.00 len: 2, id: 43
# CAR {estimated-budget=<250;300)} => {class=main-stream-hit} sup: 0.06 conf: 1.00 len: 2, id: 4
# CAR {estimated-budget=<0;50),a-list-celebrities=<4;6)} => {class=critical-success} sup: 0.06 conf: 1.00 len: 3, id: 24
# CAR {a-list-celebrities=<6;8)} => {class=critical-success} sup: 0.03 conf: 1.00 len: 2, id: 1
# CAR {estimated-budget=<100;150),a-list-celebrities=<4;6)} => {class=main-stream-hit} sup: 0.03 conf: 1.00 len: 3, id: 10
# CAR {estimated-budget=<150;200),a-list-celebrities=<4;6)} => {class=main-stream-hit} sup: 0.03 conf: 1.00 len: 3, id: 16
# CAR {estimated-budget=<200;250)} => {class=box-office-bomb} sup: 0.06 conf: 0.67 len: 2, id: 9
# CAR {estimated-budget=<0;50)} => {class=box-office-bomb} sup: 0.14 conf: 0.62 len: 2, id: 29
# CAR {a-list-celebrities=<4;6)} => {class=main-stream-hit} sup: 0.11 conf: 0.50 len: 2, id: 31
# ----------------------
# IDS accuracy 0.4857142857142857
# CBA accuracy 0.6857142857142857
# D:\programy\Anaconda3\lib\site-packages\scipy\stats\stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
df.iloc[:,1:]
# Out:
#    a-list-celebrities             class
# 0               <0;2)   box-office-bomb
# 1               <0;2)   box-office-bomb
# 2               <0;2)   box-office-bomb
# 3               <2;4)   box-office-bomb
# 4               <0;2)   box-office-bomb
# 5               <0;2)   box-office-bomb
# 6               <0;2)   box-office-bomb
# 7               <2;4)   box-office-bomb
# 8               <2;4)   box-office-bomb
# 9               <0;2)   box-office-bomb
# 10              <0;2)   box-office-bomb
# 11              <2;4)   box-office-bomb
# 12              <0;2)   box-office-bomb
# 13              <0;2)   box-office-bomb
# 14              <2;4)   box-office-bomb
# 15              <0;2)   box-office-bomb
# 16              <2;4)   box-office-bomb
# 17              <4;6)   main-stream-hit
# 18              <2;4)   main-stream-hit
# 19              <4;6)   main-stream-hit
# 20              <2;4)   main-stream-hit
# 21              <2;4)   main-stream-hit
# 22              <2;4)   main-stream-hit
# 23              <4;6)   main-stream-hit
# 24              <4;6)   main-stream-hit
# 25              <2;4)   main-stream-hit
# 26              <2;4)  critical-success
# 27              <2;4)  critical-success
# 28              <4;6)  critical-success
# 29              <4;6)  critical-success
# 30              <6;8)  critical-success
# 31              <2;4)  critical-success
# 32              <2;4)  critical-success
# 33              <4;6)  critical-success
# 34              <4;6)  critical-success

# %%
for r in cba.clf.rules:
        print(r)
# Out:
# CAR {a-list-celebrities=<0;2)} => {class=box-office-bomb} sup: 0.31 conf: 1.00 len: 2, id: 43
# CAR {estimated-budget=<250;300)} => {class=main-stream-hit} sup: 0.06 conf: 1.00 len: 2, id: 4
# CAR {estimated-budget=<0;50),a-list-celebrities=<4;6)} => {class=critical-success} sup: 0.06 conf: 1.00 len: 3, id: 24
# CAR {a-list-celebrities=<6;8)} => {class=critical-success} sup: 0.03 conf: 1.00 len: 2, id: 1
# CAR {estimated-budget=<100;150),a-list-celebrities=<4;6)} => {class=main-stream-hit} sup: 0.03 conf: 1.00 len: 3, id: 10
# CAR {estimated-budget=<150;200),a-list-celebrities=<4;6)} => {class=main-stream-hit} sup: 0.03 conf: 1.00 len: 3, id: 16
# CAR {estimated-budget=<200;250)} => {class=box-office-bomb} sup: 0.06 conf: 0.67 len: 2, id: 9
# CAR {estimated-budget=<0;50)} => {class=box-office-bomb} sup: 0.14 conf: 0.62 len: 2, id: 29
# CAR {a-list-celebrities=<4;6)} => {class=main-stream-hit} sup: 0.11 conf: 0.50 len: 2, id: 31

# %%
for r in solution_rules:
    r.print_rule()
    
    
solution_rules[0].itemset 
plot_IDS_rules(solution_rules)
plt.show()
# Out:
# If estimated-budget == <100;150), then critical-success
# If estimated-budget == <150;200), then box-office-bomb
# If estimated-budget == <0;50) and a-list-celebrities == <0;2), then main-stream-hit
# If a-list-celebrities == <4;6), then box-office-bomb
# If estimated-budget == <50;100), then box-office-bomb
# If estimated-budget == <50;100), then main-stream-hit
# If a-list-celebrities == <2;4) and estimated-budget == <50;100), then box-office-bomb

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


ys = [0, 1, 1, 0, 1, 0, 1, 1, 1, 0]

def dL(p):
    sum_ = 0
    
    sum_ += np.mean(ys) / p - (1 - np.mean(ys)) / (1 - p)
        
    return sum_

def L(p):
    sum_ = 0
    
    for i in range(len(ys)):
        sum_ += ys[i] * np.log(p) + (1 - ys[i]) * np.log(1 - p)
        
    return sum_
        
        
xs = np.linspace(0.2, 0.9, 1000)

plt.plot(xs, L(xs))
plt.show()

plt.plot(xs, dL(xs))

# %%
movies.sample(5)
# Out:
#     estimated-budget  a-list-celebrities             class
# 24               143                   5   main-stream-hit
# 3                 66                   3   box-office-bomb
# 31               152                   4  critical-success
# 28                35                   5  critical-success
# 9                132                   2   box-office-bomb

# %%
movies.plot.scatter(x="estimated-budget", y="a-list-celebrities")
plt.grid()

plt.scatter(x=movies["estimated-budget"], y=movies["a-list-celebrities"])

# %%
plot_IDS_rules([])
plt.show()

# %% [markdown]
# ## Rule size

# %%
sol_temp = copy.copy(solution_rules)

sol_temp[0].itemset

plot_IDS_rules(random.sample(list(solution_rules), 2))
plt.show()

plot_IDS_rules(random.sample(list(solution_rules), 5))
plt.show()

# %% [markdown]
# ## Fewer predicates

# %%
sol_temp = copy.copy(solution_rules)

sol_temp[0].itemset = {('estimated-budget', '<100;150)')}
sol_temp[1].itemset = {("a-list-celebrities", "<1;3)")}

plot_IDS_rules(sol_temp[0:2])
