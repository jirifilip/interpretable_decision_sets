# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

# %matplotlib inline

# %%
x, y, z = sp.symbols("x y z")


sp.plot(x*x);

sp.plotting.plot3d(x**2 + y**2)

# %%
sp.Matrix((10, 4))
# Out:
# Matrix([
# [10],
# [ 4]])
